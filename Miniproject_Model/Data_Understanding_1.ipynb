# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("./heart_attack_risk_dataset.csv")

# # เช็คว่าข้อมูลแต่ละช่องมีค่าว่างมั้ย
# nan_count = data.isnull().sum().sum()
# print('Number of NaN values:', nan_count)
df = data.sample(200)
data.head(10)
# Out:
#    Age  Gender  Smoking  Alcohol_Consumption Physical_Activity_Level    BMI  \
# 0   69  Female        1                    0                Moderate  34.61
# 1   32    Male        0                    0                Moderate  22.75
# 2   89    Male        0                    1                Moderate  35.32
# 3   78    Male        0                    1                Moderate  18.23
# 4   38  Female        1                    0                Moderate  19.82
# 5   41    Male        0                    1                Moderate  36.11
# 6   20    Male        1                    0                     Low  15.12
# 7   39  Female        0                    0                Moderate  20.78
# 8   70    Male        0                    1                    High  29.20
# 9   19  Female        0                    0                    High  35.54
#
#    Diabetes  Hypertension  Cholesterol_Level  Resting_BP  Heart_Rate  \
# 0         1             0              152.1         171          85
# 1         0             0              166.8         126         103
# 2         0             0              272.3         123         127
# 3         1             0              237.7         144         125
# 4         0             0              207.7         123         107
# 5         0             0              271.2         141         119
# 6         0             0              164.8         154          67
# 7         0             0              297.0          91         112
# 8         0             0              280.7         121          71
# 9         0             1              275.0         167          76
#
#    Family_History Stress_Level Chest_Pain_Type        Thalassemia  \
# 0               0     Moderate     Non-anginal  Reversible defect
# 1               0          Low    Asymptomatic             Normal
# 2               0          Low         Typical  Reversible defect
# 3               0          Low         Typical       Fixed defect
# 4               0         High    Asymptomatic  Reversible defect
# 5               0          Low        Atypical       Fixed defect
# 6               0          Low     Non-anginal             Normal
# 7               0          Low        Atypical             Normal
# 8               0     Moderate     Non-anginal       Fixed defect
# 9               0          Low         Typical  Reversible defect
#
#    Fasting_Blood_Sugar                   ECG_Results  Exercise_Induced_Angina  \
# 0                    0                        Normal                        0
# 1                    0              ST-T abnormality                        0
# 2                    0              ST-T abnormality                        0
# 3                    1  Left Ventricular Hypertrophy                        0
# 4                    0              ST-T abnormality                        0
# 5                    0                        Normal                        0
# 6                    0                        Normal                        0
# 7                    0              ST-T abnormality                        1
# 8                    0              ST-T abnormality                        0
# 9                    1  Left Ventricular Hypertrophy                        0
#
#    Max_Heart_Rate_Achieved Heart_Attack_Risk
# 0                      114               Low
# 1                      173          Moderate
# 2                      109               Low
# 3                      129               Low
# 4                      124          Moderate
# 5                      101              High
# 6                      176               Low
# 7                      134          Moderate
# 8                      168          Moderate
# 9                      102          Moderate

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      50000 non-null  int64
#  1   Gender                   50000 non-null  object
#  2   Smoking                  50000 non-null  int64
#  3   Alcohol_Consumption      50000 non-null  int64
#  4   Physical_Activity_Level  50000 non-null  object
#  5   BMI                      50000 non-null  float64
#  6   Diabetes                 50000 non-null  int64
#  7   Hypertension             50000 non-null  int64
#  8   Cholesterol_Level        50000 non-null  float64
#  9   Resting_BP               50000 non-null  int64
#  10  Heart_Rate               50000 non-null  int64
#  11  Family_History           50000 non-null  int64
#  12  Stress_Level             50000 non-null  object
#  13  Chest_Pain_Type          50000 non-null  object
#  14  Thalassemia              50000 non-null  object
#  15  Fasting_Blood_Sugar      50000 non-null  int64
#  16  ECG_Results              50000 non-null  object
#  17  Exercise_Induced_Angina  50000 non-null  int64
#  18  Max_Heart_Rate_Achieved  50000 non-null  int64
#  19  Heart_Attack_Risk        50000 non-null  object
# dtypes: float64(2), int64(11), object(7)
# memory usage: 7.6+ MB

# %%
object_d = data.dtypes[data.dtypes == 'object'].index.tolist()
object_d
# Out:
# ['Gender',
#  'Physical_Activity_Level',
#  'Stress_Level',
#  'Chest_Pain_Type',
#  'Thalassemia',
#  'ECG_Results',
#  'Heart_Attack_Risk']

# %%
# for i in object_d:
#     unique_data = data[i].unique()
#     d_count = data[i].value_counts()
#     print(f'{i} = {unique_data}:{d_count}') #เอาค่าไป d_count ไป plot ด้วยจ้าาา

# %%
data.describe().round(2).T
# Out:
#                            count    mean    std    min     25%     50%  \
# Age                      50000.0   53.40  20.80   18.0   35.00   53.00
# Smoking                  50000.0    0.30   0.46    0.0    0.00    0.00
# Alcohol_Consumption      50000.0    0.40   0.49    0.0    0.00    0.00
# BMI                      50000.0   27.52   7.23   15.0   21.27   27.54
# Diabetes                 50000.0    0.20   0.40    0.0    0.00    0.00
# Hypertension             50000.0    0.30   0.46    0.0    0.00    0.00
# Cholesterol_Level        50000.0  225.04  43.32  150.0  187.30  225.10
# Resting_BP               50000.0  134.43  25.91   90.0  112.00  134.00
# Heart_Rate               50000.0   94.53  20.19   60.0   77.00   94.00
# Family_History           50000.0    0.30   0.46    0.0    0.00    0.00
# Fasting_Blood_Sugar      50000.0    0.15   0.36    0.0    0.00    0.00
# Exercise_Induced_Angina  50000.0    0.20   0.40    0.0    0.00    0.00
# Max_Heart_Rate_Achieved  50000.0  149.31  28.82  100.0  124.00  149.00
#
#                             75%    max
# Age                       71.00   89.0
# Smoking                    1.00    1.0
# Alcohol_Consumption        1.00    1.0
# BMI                       33.77   40.0
# Diabetes                   0.00    1.0
# Hypertension               1.00    1.0
# Cholesterol_Level        262.60  300.0
# Resting_BP               157.00  179.0
# Heart_Rate               112.00  129.0
# Family_History             1.00    1.0
# Fasting_Blood_Sugar        0.00    1.0
# Exercise_Induced_Angina    0.00    1.0
# Max_Heart_Rate_Achieved  174.00  199.0

# %%
n_cols = 3
n_rows = (len(object_d)+n_cols-1)// n_cols
fig , axes=plt.subplots(n_rows,n_cols, figsize = (5*n_cols,5*n_rows))
for index,column in enumerate(object_d):
    row = index//n_cols
    col = index%n_cols
    sns.countplot(data=data,x=column,ax=axes[row,col])
    axes[row,col].set_title(f'{column}')
    axes[row,col].set_xlabel('')
    axes[row,col].set_ylabel('count')
if len(object_d) < n_rows * n_cols:
    for idx in range(len(object_d), n_rows * n_cols):
        fig.delaxes(axes.flatten()[idx])

plt.tight_layout()
plt.show()

# %% [markdown]
# จากข้อมูลการเป็นโรคหัวใจจะมีความเสี่ยงน้อยมากกว่าความเสี่ยงมาก ซึ่งก็เป็นปกติเพราะส่วนมากคนปกติมีความเสี่ยงที่จะเป็นโรคน้อยอยู่แล้วทำให้เกิด bias เลยต้องทำ sensitivity

# %%
data_n = data.select_dtypes(include='number')
data_D = (data_n-data_n.mean())/data_n.std()
plt.figure(figsize=(8, 6))
sns.boxplot(data=data_n, palette='pastel')


plt.title('Box Plot of Selected Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation=90)

plt.show()
# box plot ทำไปเพื่อดู feature outliner อันที่มีวงกลม

# %%
import matplotlib.pyplot as plt
import seaborn as sns

n_cols = 3  # จำนวนคอลัมน์
outlier_d = ['Diabetes', 'Fasting_Blood_Sugar', 'Exercise_Induced_Angina']
n_rows = 1  # ใช้แค่ 1 แถว

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 5 * n_rows))  # สร้าง subplots 1 row, 3 columns

for index, column in enumerate(outlier_d):
    sns.histplot(data=data, x=column, ax=axes[index])  # ใช้ axes[index] แทน row/col
    axes[index].set_title(f'{column}')
    axes[index].set_xlabel('')
    axes[index].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 6))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(data_n.corr(),cmap='flare', vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
Data_plot = df.select_dtypes(include='number')

Data_plot['Heart_Attack_Risk'] = df['Heart_Attack_Risk']

# ใช้ pairplot = plot เทียบระหว่าง feature เฉพาะคอลัมน์ที่เป็นตัวเลข
sns.pairplot(Data_plot, hue="Heart_Attack_Risk")
# จากรูป data ไม่ได้มี pattern แบบ correlation กันเนื่องจาก data ส่วนใหญ่เป็น 0 และ 1 ทำให้ linear แก้ไม่ได้เลยตัดปัญหาการแก้โดยใช้ linear ออกไปเพราะ data ไม่มี correlation กัน

# %%
df_copy = data.copy()
bins = [18, 25, 40, 60, 90]
labels = ['18-25', '26-40', '41-60', '60+']
df_copy['Age Group'] = pd.cut(df_copy['Age'], bins=bins, labels=labels, right=False)
color_t  = 'flare'
# Create the countplot with custom colors
plt.figure(figsize=(7, 5))
sns.countplot(data=df_copy, x='Age Group', hue='Heart_Attack_Risk', palette=color_t)
plt.title('Heart_Attack_Risk by Age Group')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Heart_Attack_Risk')
plt.show()

# %%
bins = [ 149, 200,239, 301]
labels = ['<200', '200-239', '240+']
df_copy['Cholesterol_Level Group'] = pd.cut(df_copy['Cholesterol_Level'], bins=bins, labels=labels, right=False)

# Create the countplot with custom colors
plt.figure(figsize=(7, 5))
sns.countplot(data=df_copy, x='Cholesterol_Level Group', hue='Heart_Attack_Risk', palette=color_t)
plt.title('Heart_Attack_Risk by Cholesterol_Level Group')
plt.xlabel('Cholesterol_Level')
plt.ylabel('Count')
plt.legend(title='Heart_Attack_Risk')
plt.show()

# %%
df_copy['Smoking Group'] = df_copy['Smoking'].map({0: 'not Smoking', 1: 'Smoking'})
# นับจำนวนทั้งหมดในแต่ละกลุ่ม (สูบ vs ไม่สูบ)
total_counts = df_copy['Smoking Group'].value_counts()

# นับจำนวนคนที่มีความเสี่ยงระดับกลางและสูงในแต่ละกลุ่ม
risk_counts = df_copy[df_copy['Heart_Attack_Risk'].isin([ 'High'])]['Smoking Group'].value_counts()

# คำนวณเปอร์เซ็นต์ของคนที่มีความเสี่ยงระดับกลางและสูง
risk_percent = (risk_counts / total_counts) * 100

# แสดงผลลัพธ์
print("อัตราความเสี่ยงระดับ High:")
print(risk_percent)
# Create the countplot with custom colors
plt.figure(figsize=(7, 5))
sns.countplot(data=df_copy, x='Smoking Group', hue='Heart_Attack_Risk', palette=color_t)
plt.title('Heart_Attack_Risk by Smoking')
plt.xlabel('Smoking')
plt.ylabel('Count')
plt.legend(title='Heart_Attack_Risk')
plt.show()
# Out:
# อัตราความเสี่ยงระดับ High:
# Smoking Group
# not Smoking    20.031928
# Smoking        20.407479
# Name: count, dtype: float64

# %%
# นับจำนวนทั้งหมดในแต่ละกลุ่ม (สูบ vs ไม่สูบ)
total_counts = df_copy['Smoking Group'].value_counts()

# นับจำนวนคนที่มีความเสี่ยงระดับกลางและสูงในแต่ละกลุ่ม
risk_counts = df_copy[df_copy['Heart_Attack_Risk'].isin(['High'])]['Smoking Group'].value_counts()

# คำนวณเปอร์เซ็นต์ของคนที่มีความเสี่ยงระดับกลางและสูง
risk_percent = (risk_counts / total_counts) * 100

# แสดงผลลัพธ์
print("อัตราความเสี่ยงระดับ Medium และ High:")
print(risk_percent)

# สร้างกราฟเปรียบเทียบ
plt.figure(figsize=(6, 4))
sns.barplot(x=risk_percent.index, y=risk_percent.values, palette=['green', 'red'])
plt.title('Percentage of Medium & High Heart Attack Risk')
plt.xlabel('Smoking Status')
plt.ylabel('Risk Percentage (%)')
plt.ylim(0, 100)
plt.show()
# Out:
# อัตราความเสี่ยงระดับ Medium และ High:
# Smoking Group
# not Smoking    20.031928
# Smoking        20.407479
# Name: count, dtype: float64
# /var/folders/24/x393tmk92ls_5g0jvpjh7m840000gn/T/ipykernel_78577/3446244176.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=risk_percent.index, y=risk_percent.values, palette=['green', 'red'])

# %%
df_copy['Alcohol_Consumption Group'] = df_copy['Alcohol_Consumption'].map({0: 'not Alcohol_Consumption', 1: 'Alcohol_Consumption'})
total_counts = df_copy['Alcohol_Consumption Group'].value_counts()

# นับจำนวนคนที่มีความเสี่ยงระดับกลางและสูงในแต่ละกลุ่ม
risk_counts = df_copy[df_copy['Heart_Attack_Risk'].isin(['High'])]['Alcohol_Consumption Group'].value_counts()

# คำนวณเปอร์เซ็นต์ของคนที่มีความเสี่ยงระดับกลางและสูง
risk_percent = (risk_counts / total_counts) * 100

# แสดงผลลัพธ์
print("อัตราความเสี่ยงระดับ High:")
print(risk_percent)

# Create the countplot with custom colors
plt.figure(figsize=(7, 5))
sns.countplot(data=df_copy, x='Alcohol_Consumption Group', hue='Heart_Attack_Risk', palette=color_t)
plt.title('Heart_Attack_Risk by Alcohol_Consumption ')
plt.xlabel('Alcohol_Consumption')
plt.ylabel('Count')
plt.legend(title='Heart_Attack_Risk')
plt.show()
# Out:
# อัตราความเสี่ยงระดับ High:
# Alcohol_Consumption Group
# not Alcohol_Consumption    20.026086
# Alcohol_Consumption        20.319419
# Name: count, dtype: float64

# %%
# นับจำนวนทั้งหมดในแต่ละกลุ่ม (ดื่ม vs ไม่ดื่ม)
total_counts = df_copy['Alcohol_Consumption Group'].value_counts()

# นับจำนวนคนที่มีความเสี่ยงระดับกลางและสูงในแต่ละกลุ่ม
risk_counts = df_copy[df_copy['Heart_Attack_Risk'].isin(['High'])]['Alcohol_Consumption Group'].value_counts()

# คำนวณเปอร์เซ็นต์ของคนที่มีความเสี่ยงระดับกลางและสูง
risk_percent = (risk_counts / total_counts) * 100

# แสดงผลลัพธ์
print("อัตราความเสี่ยงระดับ Medium และ High:")
print(risk_percent)
print(total_counts,df_copy['Heart_Attack_Risk'].isin(['High']).value_counts())
# Out:
# อัตราความเสี่ยงระดับ Medium และ High:
# Alcohol_Consumption Group
# not Alcohol_Consumption    20.026086
# Alcohol_Consumption        20.319419
# Name: count, dtype: float64
# Alcohol_Consumption Group
# not Alcohol_Consumption    29901
# Alcohol_Consumption        20099
# Name: count, dtype: int64 Heart_Attack_Risk
# False    39928
# True     10072
# Name: count, dtype: int64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        50000 non-null  int64
#  1   Gender                     50000 non-null  object
#  2   Smoking                    50000 non-null  int64
#  3   Alcohol_Consumption        50000 non-null  int64
#  4   Physical_Activity_Level    50000 non-null  object
#  5   BMI                        50000 non-null  float64
#  6   Diabetes                   50000 non-null  int64
#  7   Hypertension               50000 non-null  int64
#  8   Cholesterol_Level          50000 non-null  float64
#  9   Resting_BP                 50000 non-null  int64
#  10  Heart_Rate                 50000 non-null  int64
#  11  Family_History             50000 non-null  int64
#  12  Stress_Level               50000 non-null  object
#  13  Chest_Pain_Type            50000 non-null  object
#  14  Thalassemia                50000 non-null  object
#  15  Fasting_Blood_Sugar        50000 non-null  int64
#  16  ECG_Results                50000 non-null  object
#  17  Exercise_Induced_Angina    50000 non-null  int64
#  18  Max_Heart_Rate_Achieved    50000 non-null  int64
#  19  Heart_Attack_Risk          50000 non-null  object
#  20  Age Group                  50000 non-null  category
#  21  Cholesterol_Level Group    50000 non-null  category
#  22  Smoking Group              50000 non-null  object
#  23  Alcohol_Consumption Group  50000 non-null  object
# dtypes: category(2), float64(2), int64(11), object(9)
# memory usage: 8.5+ MB
